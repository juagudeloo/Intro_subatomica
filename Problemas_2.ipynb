# %%
# %display latex
x,y,z,t, C1, C2, C3, C4 = var("x, y, z, t, C_1, C_2, C_3, C_4")
q = 1
B = 1
m = 1
E = 1
ω = q*B/m

# %%
yy(t) = C1*cos(ω*t)+C2*sin(ω*t)+(E/B)*t+C3
yy
# Out:
# t |--> C_1*cos(t) + C_2*sin(t) + C_3 + t

# %%
zz(t) = -C1*sin(ω*t) + C2*cos(ω*t)+C4
zz
# Out:
# t |--> C_2*cos(t) - C_1*sin(t) + C_4

# %%
C1 = 1
C2 = 0
C3 = -1
C4 = 0

zz(t) = -C1*sin(ω*t) + C2*cos(ω*t)+C4
yy(t) = C1*cos(ω*t)+C2*sin(ω*t)+(E/B)*t+C3
f = (0,yy,zz)

# %%
def axes(xmin=-1,xmax=1,ymin=-1,ymax=1,zmin=-1,zmax=1,**kwds):
    ex = vector((1,0,0))
    ey = vector((0,1,0))
    ez = vector((0,0,1))
    G =  line3d([xmin*ex,xmax*ex],**kwds)
    G += line3d([ymin*ey,ymax*ey],**kwds)
    G += line3d([zmin*ez,zmax*ez],**kwds)
    return G

# P = implicit_plot3d(lambda x,y,z: x, (-2,2), (-2,2), (-2,2), color = "blue", opacity=0.2)
# Q = implicit_plot3d(lambda x,y,z: y, (-2,2), (-2,2), (-2,2), color = "red", opacity=0.2)
# R = implicit_plot3d(lambda x,y,z: z, (-2,2), (-2,2), (-2,2), color = "green", opacity= 0.2)
S = axes(xmin=-2, ymin=-2, zmin=-2, xmax=2, ymax=2, zmax=2, color='red',thickness=2)


W = parametric_plot3d(f, (0,20), thickness=3)
show(S+W)
# Out:
# Graphics3d Object
